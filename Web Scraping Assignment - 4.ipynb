# %% [markdown]
# 1. QUESTION --> SOLUTION

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()
url = "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"
driver.get(url)

# %%
try:
    Table_Body = driver.find_element(By.XPATH,'//table[@class="sortable wikitable sticky-header static-row-numbers sort-under col3center col4right jquery-tablesorter"]/tbody')

    
except Exception as e:
    print(f"An error occurred: {e}")

# %%
data = []

# %%
try:
    for tr in Table_Body.find_elements(By.XPATH, '//tr'):
        row = [item.text for item in tr.find_elements(By.XPATH, './/td')]
        data.append(row)
        
except as Exception as e:
    print(f"An error occurred: {e}")

# %%
data
# Out:
# [['',
#   "hide\nThis section has multiple issues. Please help improve it or discuss these issues on the talk page. (Learn how and when to remove these template messages)\nThis section's factual accuracy is disputed. (February 2024)\nThis section needs expansion with: Information to the reader the auto-generated playlist from YouTube is not an index of a video popularity due to the views-counting algorithm. You can help by adding to it. (February 2024)",
#   '',
#   "This section's factual accuracy is disputed. (February 2024)",
#   '',
#   'This section needs expansion with: Information to the reader the auto-generated playlist from YouTube is not an index of a video popularity due to the views-counting algorithm. You can help by adding to it. (February 2024)'],
#  ['', "This section's factual accuracy is disputed. (February 2024)"],
#  ['',
# ...

# %%
# Scrape all details of  Rank, Name, Artist , Views, Date

# %% [markdown]
# 2. QUESTION --> SOLUTION -->

# %%
driver = webdriver.Chrome()
url = "https://www.bcci.tv/"
driver.get(url)

# %%
link = driver.find_element(By.XPATH,'//div[@class="imw-tabs international-tabs"][1]/a[2]')

# %%
link.click()

# %%
try:
    Series_Name = driver.find_elements(By.XPATH,'//h5[@class="match-tournament-name ng-binding"]')
    Series = []
    for i in Series_Name:
        names = i.text
        Series.append(names)

    
except Exception as e:
    print(f"An error occurred: {e}")

# %%
Series_Name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="3c0afbd54ef6f22c1a142d2c8b8bfc2a", element="880E84907990351ECD04E2D8CA31FF32_element_191")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3c0afbd54ef6f22c1a142d2c8b8bfc2a", element="880E84907990351ECD04E2D8CA31FF32_element_192")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3c0afbd54ef6f22c1a142d2c8b8bfc2a", element="880E84907990351ECD04E2D8CA31FF32_element_193")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3c0afbd54ef6f22c1a142d2c8b8bfc2a", element="880E84907990351ECD04E2D8CA31FF32_element_194")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3c0afbd54ef6f22c1a142d2c8b8bfc2a", element="880E84907990351ECD04E2D8CA31FF32_element_195")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3c0afbd54ef6f22c1a142d2c8b8bfc2a", element="880E84907990351ECD04E2D8CA31FF32_element_196")>]

# %%
Series
# Out:
# ['ENGLAND TOUR OF INDIA 2023-24',
#  'INDIA TOUR OF ZIMBABWE 2024',
#  'INDIA TOUR OF ZIMBABWE 2024',
#  'INDIA TOUR OF ZIMBABWE 2024',
#  'INDIA TOUR OF ZIMBABWE 2024',
#  'INDIA TOUR OF ZIMBABWE 2024']

# %%
try:
    Place_Name = driver.find_elements(By.XPATH,'//div[@class="match-place ng-scope"]/span')
    Places = []
    for i in Place_Name:
        names = i.text
        Places.append(names)

except Exception as e:
    print(f"An error occurred: {e}")

# %%
Places
# Out:
# ['Himachal Pradesh Cricket Association Stadium,',
#  'Dharamsala',
#  'Harare Sports Club,',
#  'Harare',
#  'Harare Sports Club,',
#  'Harare',
#  'Harare Sports Club,',
#  'Harare',
#  'Harare Sports Club,',
#  'Harare',
#  'Harare Sports Club,',
#  'Harare']

# %%
try:
    dates = driver.find_elements(By.XPATH,'//div[@class="match-dates ng-binding"]')
    Dates = []
    for i in dates:
        dates_ = i.text
        Dates.append(dates_)
        
except Exception as e:
    print(f"An error occurred: {e}")

# %%
Dates
# Out:
# ['7 MARCH, 2024',
#  '6 JULY, 2024',
#  '7 JULY, 2024',
#  '10 JULY, 2024',
#  '13 JULY, 2024',
#  '14 JULY, 2024']

# %%
try:
    time = driver.find_elements(By.XPATH,'//div[@class="match-time no-margin ng-binding"]')
    Time = []
    for i in time:
        time_ = i.text
        Time.append(time_)
        
except Exception as e:
    print(f"An error occurred: {e}")

# %%
Time
# Out:
# ['9:30 AM IST',
#  '8:00 PM IST',
#  '8:00 PM IST',
#  '8:00 PM IST',
#  '8:00 PM IST',
#  '8:00 PM IST']

# %% [markdown]
# 3. QUESTION--> SOLUTION-->

# %%
driver = webdriver.Chrome()
url = "https://www.statisticstimes.com/"
driver.get(url)

# %%
link2 = driver.find_element(By.XPATH,'//ul[@style="list-style-type:none;margin-left:20px;"]/li/a[1]')

# %%
link2.click()

# %%
Table_Body = driver.find_element(By.XPATH,'//table[@id="table_id"]')

# %%
Table_Body
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="474acc63c6a7c0fafba34f7047725873", element="D8F3DF09941881653EF901B2B6908106_element_106")>

# %%
data = []

# %%
try:
    for tr in Table_Body.find_elements(By.XPATH, '//tr'):
        row = [item.text for item in tr.find_elements(By.XPATH, './/td')]
        data.append(row)

except Exception as e:
    print(f"An error occurred: {e}")

# %%
data
# Out:
# [['Source', 'Ministry of Statistics and Programme Implementation (17)'],
#  ['Date', '21 Dec 2023'],
#  [],
#  [],
#  ['1', 'Maharashtra', '-', '3,108,022', '13.24%', '417.163', '-', '2,027,971'],
#  ['2',
#   'Tamil Nadu',
#   '2,364,514',
#   '2,071,286',
#   '8.82%',
#   '278.011',
#   '1,453,321',
#   '1,343,287'],
#  ['3',
#   'Uttar Pradesh',
#   '2,257,575',
#   '1,974,532',
#   '8.41%',
#   '265.024',
#   '1,304,678',
#   '1,204,660'],
#  ['4',
#   'Karnataka',
#   '2,241,368',
#   '1,962,725',
#   '8.36%',
#   '263.440',
#   '1,326,319',
#   '1,229,713'],
#  ['5', 'Gujarat', '-', '1,937,066', '8.25%', '259.996', '-', '1,372,204'],
#  ['6',
#   'West Bengal',
#   '1,554,992',
#   '1,363,926',
#   '5.81%',
#   '183.068',
#   '854,023',
#   '787,758'],
#  ['7',
#   'Rajasthan',
#   '1,413,620',
#   '1,218,193',
#   '5.19%',
#   '163.507',
#   '799,449',
#   '738,922'],
#  ['8',
#   'Madhya Pradesh',
#   '1,322,821',
#   '1,136,137',
#   '4.84%',
#   '152.494',
#   '643,124',
# ...

# %%
#) Scraped Following Details State, GSDP(18-19)- at current prices, GSDP(19-20)- at current prices, Share(18-19), GDP($ billion)

# %% [markdown]
# 4. QUESTION--> SOLUTION-->

# %%
driver = webdriver.Chrome()
url = "https://github.com/"
driver.get(url)

# %%
link_1 = driver.find_element(By.XPATH,'//ul[@data-view-component="true"]/li[8]/a')

# %%
link_1.click()

# %%
link_2 = driver.find_element(By.XPATH,'//div[@class="d-flex flex-wrap flex-items-center flex-justify-center flex-md-justify-start text-center text-md-left"]/a[3]')

# %%
link_2.click()

# %%
try:
    title = driver.find_elements(By.XPATH,'//span[@class="text-normal"]')
    Repository_title = []
    for i in title:
        title_ = i.text
        Repository_title.append(title_)
        
except Exception as e:
    print(f"An error occurred: {e}")

# %%
Repository_title
# Out:
# ['WongKinYiu /',
#  'public-apis /',
#  'Azure /',
#  'vvbbnn00 /',
#  'tigerbeetle /',
#  'FuelLabs /',
#  'FuelLabs /',
#  'MHSanaei /',
#  'google /',
#  'Eladlev /',
#  'mouredev /',
#  'ossu /',
#  'FuelLabs /',
#  'FuelLabs /',
#  'toeverything /',
#  'MDK8888 /',
#  'KillianLucas /',
#  'zksync /',
#  'electric-sql /',
#  'massgravel /',
#  'ollama /',
#  'angular /',
#  'ashishps1 /',
#  '1c7 /',
#  'laurent22 /']

# %%
try : 
    description = driver.find_elements(By.XPATH,'//p[@class="col-9 color-fg-muted my-1 pr-4"]')
    Repository_description = []
    for i in description:
        description_ = i.text
        Repository_description.append(description_)
    
except Exception as e:
    print(f"An error occurred: {e}")

# %%
Repository_description
# Out:
# ['Implementation of paper - YOLOv9: Learning What You Want to Learn Using Programmable Gradient Information',
#  'A collective list of free APIs',
#  'The Python Risk Identification Tool for generative AI (PyRIT) is an open access automation framework to empower security professionals and machine learning engineers to proactively find risks in their generative AI systems.',
#  '该项目可以让你通过订阅的方式使用Cloudflare WARP+，自动获取流量。This project enables you to use Cloudflare WARP+ through subscription, automatically acquiring traffic.',
#  'The distributed financial transactions database designed for mission critical safety and performance.',
#  'Rust full node implementation of the Fuel v2 protocol.',
#  '🌴 Empowering everyone to build reliable and efficient smart contracts.',
#  'Xray panel supporting multi-protocol multi-user expire day & traffic & ip limit (Vmess & Vless & Trojan & ShadowSocks & Wireguard)',
#  "lightweight, standalone C++ inference engine for Google's Gemma models.",
# ...

# %%
try : 
    language_used = driver.find_elements(By.XPATH,'//span[@itemprop="programmingLanguage"]')
    languages = []
    for i in language_used:
        language_ = i.text
        languages.append(language_)
    
except Exception as e:
    print(f"An error occurred: {e}")

# %%
languages
# Out:
# ['Python',
#  'Python',
#  'Python',
#  'Python',
#  'Zig',
#  'Rust',
#  'Rust',
#  'JavaScript',
#  'C++',
#  'Python',
#  'Python',
#  'TypeScript',
#  'Rust',
#  'TypeScript',
#  'Python',
#  'Python',
#  'TypeScript',
#  'Batchfile',
#  'Go',
#  'TypeScript',
#  'TypeScript']

# %% [markdown]
# 5. QUESTION--> SOLUTION-->

# %%
driver = webdriver.Chrome()
url = "https://www.billboard.com/"
driver.get(url)

# %%
link_1 = driver.find_element(By.XPATH,'//div[@class="u-flex-grow-0 lrv-u-text-align-center"]/span/a')

# %%
link_1.click()

# %%
try :
    songs = driver.find_elements(By.XPATH,'//div[@class="o-chart-results-list-row-container"]/ul/li/ul/li/h3') 
    song_names = []
    for i in songs:
        title_ = i.text
        song_names.append(title_)
    
except Exception as e:
    print(f"An error occurred: {e}")

# %%
song_names
# Out:
# ["Texas Hold 'Em",
#  'Lovin On Me',
#  'Lose Control',
#  'Carnival',
#  'Beautiful Things',
#  'Snooze',
#  'Cruel Summer',
#  'Greedy',
#  'I Remember Everything',
#  'Agora Hills',
#  'Yes, And?',
#  'Stick Season',
#  'Fast Car',
#  'Water',
#  'Last Night',
#  'Redrum',
#  "Thinkin' Bout Me",
#  "Is It Over Now? (Taylor's Version) [From The Vault]",
#  'Pretty Little Poison',
#  'Flowers',
#  'Paint The Town Red',
#  'Houdini',
#  'Made For Me',
#  'Never Lose Me',
#  'La Diabla',
#  'Where The Wild Things Are',
#  'Training Season',
#  'The Painter',
#  'Feather',
#  'What Was I Made For?',
#  'Rich Baby Daddy',
#  'Whatever She Wants',
#  'Truck Bed',
#  'Selfish',
#  'Everybody',
#  'Vampire',
#  'Wild Ones',
#  'On My Mama',
#  'Praise Jah In The Moonlight',
#  'Save Me',
#  'Exes',
#  'Breathe',
#  'Dance The Night',
#  'Need A Favor',
#  'Surround Sound',
#  'World On Fire',
#  'Yeah!',
#  'Burn It Down',
#  'Good Good',
#  'La Victima',
#  'End Of Beginning',
# ...

# %%
try:
    song_information = driver.find_elements(By.XPATH,'//div[@class="o-chart-results-list-row-container"]/ul/li/ul/li/span')
    Song_information = []
    for i in song_information:
        titles_ = i.text
        Song_information.append(titles_)
    
except Exception as e:
    print(f"An error occurred: {e}")

# %%
Song_information
# Out:
# ['Beyonce',
#  '2',
#  '1',
#  '2',
#  'Jack Harlow',
#  '1',
#  '1',
#  '15',
#  'Teddy Swims',
#  '5',
#  '2',
#  '28',
#  '¥$: Kanye West & Ty Dolla $ign Featuring Rich The Kid & Playboi Carti',
#  '3',
#  '3',
#  '2',
#  'Benson Boone',
#  '4',
#  '3',
#  '5',
#  'SZA',
#  '7',
#  '2',
#  '62',
#  'Taylor Swift',
#  '6',
#  '1',
#  '42',
#  'Tate McRae',
#  '9',
#  '3',
#  '23',
#  'Zach Bryan Featuring Kacey Musgraves',
#  '8',
#  '1',
#  '26',
#  'Doja Cat',
#  '12',
#  '7',
#  '22',
#  'Ariana Grande',
#  '31',
#  '1',
#  '6',
#  'Noah Kahan',
#  '10',
#  '10',
#  '21',
#  'Luke Combs',
#  '11',
#  '2',
#  '48',
#  'Tyla',
#  '13',
#  '7',
#  '21',
#  'Morgan Wallen',
#  '14',
#  '1',
#  '56',
#  '21 Savage',
#  '15',
#  '5',
#  '6',
#  'Morgan Wallen',
#  '16',
#  '7',
#  '51',
#  'Taylor Swift',
#  '18',
#  '1',
#  '17',
#  'Warren Zeiders',
#  '24',
#  '19',
#  '24',
#  'Miley Cyrus',
#  '17',
#  '1',
#  '53',
#  'Doja Cat',
#  '19',
#  '1',
#  '29',
#  'Dua Lipa',
# ...

# %%
# Scraped Artist Name, Last week rank, Peak rank, Weeks on board

# %% [markdown]
# 6. QUESTION--> SOLUTION-->

# %%
driver = webdriver.Chrome()
url = "https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare"
driver.get(url)

# %%
Table_body = driver.find_element(By.XPATH,'//table[@class="in-article sortable"]')

# %%
Table_body
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="dab37ab5058faf1d5b279f64a3a6ae04", element="15F0A0DC6A146FA5B3133A6BFA86AB82_element_17")>

# %%
data = []

# %%
try:
    for tr in Table_body.find_elements(By.XPATH, '//tr'):
        row = [item.text for item in tr.find_elements(By.XPATH, './/td')]
        data.append(row)
    
except Exception as e:
    print(f"An error occurred: {e}")

# %%
data
# Out:
# [[],
#  ['SOURCE: NIELSEN BOOK SCAN'],
#  ['1',
#   'Da Vinci Code,The',
#   'Brown, Dan',
#   '5,094,805',
#   'Transworld',
#   'Crime, Thriller & Adventure'],
#  ['2',
#   'Harry Potter and the Deathly Hallows',
#   'Rowling, J.K.',
#   '4,475,152',
#   'Bloomsbury',
#   "Children's Fiction"],
#  ['3',
#   "Harry Potter and the Philosopher's Stone",
#   'Rowling, J.K.',
#   '4,200,654',
#   'Bloomsbury',
#   "Children's Fiction"],
#  ['4',
#   'Harry Potter and the Order of the Phoenix',
#   'Rowling, J.K.',
#   '4,179,479',
#   'Bloomsbury',
#   "Children's Fiction"],
#  ['5',
#   'Fifty Shades of Grey',
#   'James, E. L.',
#   '3,758,936',
#   'Random House',
#   'Romance & Sagas'],
#  ['6',
#   'Harry Potter and the Goblet of Fire',
#   'Rowling, J.K.',
#   '3,583,215',
#   'Bloomsbury',
#   "Children's Fiction"],
#  ['7',
#   'Harry Potter and the Chamber of Secrets',
#   'Rowling, J.K.',
#   '3,484,047',
#   'Bloomsbury',
#   "Children's Fiction"],
#  ['8',
# ...

# %% [markdown]
# 7.QUESTION--> SOLUTION-->

# %%
driver = webdriver.Chrome()
url = "https://www.imdb.com/list/ls512407256/"
driver.get(url)

# %%
Name = driver.find_elements(By.XPATH,'//h3[@class="ipc-title__text"]')

# %%
Name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="82f271425d82c222461ebe546604f160", element="6304846B710882B5C06B71D0ABD5CE95_element_206")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="82f271425d82c222461ebe546604f160", element="6304846B710882B5C06B71D0ABD5CE95_element_207")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="82f271425d82c222461ebe546604f160", element="6304846B710882B5C06B71D0ABD5CE95_element_208")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="82f271425d82c222461ebe546604f160", element="6304846B710882B5C06B71D0ABD5CE95_element_209")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="82f271425d82c222461ebe546604f160", element="6304846B710882B5C06B71D0ABD5CE95_element_210")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="82f271425d82c222461ebe546604f160", element="6304846B710882B5C06B71D0ABD5CE95_element_211")>,
# ...

# %%
try:
    tv_shows_names = driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]/a')
    TV_Shows_names = []
    for i in tv_shows_names:
        titles_ = i.text
        TV_Shows_names.append(titles_)
        
except Exception as e:
    print(f"An error occurred: {e}")

# %%
TV_Shows_names
# Out:
# ['Game of Thrones',
#  'Stranger Things',
#  'The Walking Dead',
#  '13 Reasons Why',
#  'The 100',
#  'Orange Is the New Black',
#  'Riverdale',
#  "Grey's Anatomy",
#  'The Flash',
#  'Arrow',
#  'Money Heist',
#  'The Big Bang Theory',
#  'Black Mirror',
#  'Sherlock',
#  'Vikings',
#  'Pretty Little Liars',
#  'The Vampire Diaries',
#  'American Horror Story',
#  'Breaking Bad',
#  'Lucifer',
#  'Supernatural',
#  'Prison Break',
#  'How to Get Away with Murder',
#  'Teen Wolf',
#  'The Simpsons',
#  'Once Upon a Time',
#  'Narcos',
#  'Daredevil',
#  'Friends',
#  'How I Met Your Mother',
#  'Suits',
#  'Mr. Robot',
#  'The Originals',
#  'Supergirl',
#  'Gossip Girl',
#  'Sense8',
#  'Gotham',
#  'Westworld',
#  'Jessica Jones',
#  'Modern Family',
#  'Rick and Morty',
#  'Shadowhunters',
#  'The End of the F***ing World',
#  'House of Cards',
#  'Dark',
#  'Elite',
#  'Sex Education',
#  'Shameless',
#  'New Girl',
#  'Agents of S.H.I.E.L.D.',
#  'Game of Thrones',
#  'You',
# ...

# %%
try:
    votes = driver.find_elements(By.XPATH,'//span[@name="nv"]')
    Votes = []
    for i in votes:
        titles_ = i.text
        Votes.append(titles_)
        
except Exception as e:
    print(f"An error occurred: {e}")

# %%
Votes
# Out:
# ['2,262,002',
#  '1,320,102',
#  '1,071,973',
#  '313,431',
#  '273,343',
#  '318,655',
#  '154,353',
#  '338,272',
#  '366,922',
#  '444,742',
#  '526,696',
#  '861,102',
#  '633,240',
#  '989,342',
#  '576,032',
#  '177,351',
#  '347,064',
#  '341,271',
#  '2,110,079',
#  '352,699',
#  '479,074',
#  '574,826',
#  '165,324',
#  '162,030',
#  '433,031',
#  '235,942',
#  '465,788',
#  '471,302',
#  '1,078,720',
#  '723,961',
#  '472,213',
#  '415,154',
#  '146,691',
#  '129,116',
#  '191,516',
#  '162,175',
#  '239,825',
#  '529,651',
#  '225,666',
#  '477,237',
#  '594,675',
#  '69,861',
#  '217,284',
#  '528,318',
#  '437,713',
#  '89,856',
#  '346,852',
#  '279,837',
#  '243,702',
#  '225,144',
#  '2,262,002',
#  '295,826',
#  '1,320,102',
#  '759,515',
#  '1,071,973',
#  '142,826',
#  '313,431',
#  '361,915',
#  '273,343',
#  '277,233',
#  '318,655',
#  '590,313',
#  '154,353',
#  '637,606',
#  '338,272',
#  '505,447',
#  '366,922',
#  '63,657',
#  '444,742',
#  '116,459',
# ...

# %%
try:
    genre = driver.find_elements(By.XPATH,'//span[@class="genre"]')
    Genres = []
    for i in genre:
        titles_ = i.text
        Genres.append(titles_)
    
except Exception as e:
    print(f"An error occurred: {e}")

# %%
Genres
# Out:
# ['Action, Adventure, Drama',
#  'Drama, Fantasy, Horror',
#  'Drama, Horror, Thriller',
#  'Drama, Mystery, Thriller',
#  'Drama, Mystery, Sci-Fi',
#  'Comedy, Crime, Drama',
#  'Crime, Drama, Mystery',
#  'Drama, Romance',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Crime',
#  'Action, Crime, Drama',
#  'Comedy, Romance',
#  'Drama, Mystery, Sci-Fi',
#  'Crime, Drama, Mystery',
#  'Action, Adventure, Drama',
#  'Drama, Mystery, Romance',
#  'Drama, Fantasy, Horror',
#  'Drama, Horror, Sci-Fi',
#  'Crime, Drama, Thriller',
#  'Crime, Drama, Fantasy',
#  'Drama, Fantasy, Horror',
#  'Action, Crime, Drama',
#  'Crime, Drama, Mystery',
#  'Action, Drama, Fantasy',
#  'Animation, Comedy',
#  'Adventure, Fantasy, Romance',
#  'Biography, Crime, Drama',
#  'Action, Crime, Drama',
#  'Comedy, Romance',
#  'Comedy, Drama, Romance',
#  'Comedy, Drama',
#  'Crime, Drama, Thriller',
#  'Drama, Fantasy, Horror',
#  'Action, Adventure, Drama',
#  'Drama, Romance',
# ...

# %%
try:
    year_span = driver.find_elements(By.XPATH,'//span[@class="lister-item-year text-muted unbold"]')
    Year_span = []
    for i in year_span:
        titles_ = i.text
        Year_span.append(titles_)
        
except Exception as e:
    print(f"An error occurred: {e}")

# %%
Year_span
# Out:
# ['(2011–2019)',
#  '(2016–2025)',
#  '(2010–2022)',
#  '(2017–2020)',
#  '(2014–2020)',
#  '(2013–2019)',
#  '(2017–2023)',
#  '(2005– )',
#  '(2014–2023)',
#  '(2012–2020)',
#  '(2017–2021)',
#  '(2007–2019)',
#  '(2011– )',
#  '(2010–2017)',
#  '(2013–2020)',
#  '(2010–2017)',
#  '(2009–2017)',
#  '(2011– )',
#  '(2008–2013)',
#  '(2016–2021)',
#  '(2005–2020)',
#  '(2005–2017)',
#  '(2014–2020)',
#  '(2011–2017)',
#  '(1989– )',
#  '(2011–2018)',
#  '(I) (2015–2017)',
#  '(2015–2018)',
#  '(1994–2004)',
#  '(2005–2014)',
#  '(2011–2019)',
#  '(2015–2019)',
#  '(2013–2018)',
#  '(2015–2021)',
#  '(2007–2012)',
#  '(2015–2018)',
#  '(2014–2019)',
#  '(2016–2022)',
#  '(2015–2019)',
#  '(2009–2020)',
#  '(2013– )',
#  '(2016–2019)',
#  '(2017–2019)',
#  '(2013–2018)',
#  '(2017–2020)',
#  '(2018–2024)',
#  '(2019–2023)',
#  '(2011–2021)',
#  '(2011–2018)',
#  '(2013–2020)',
#  '(2011–2019)',
#  '(2018–2024)',
#  '(2016–2025)',
#  '(2006–2013)',
#  '(2010–2022)',
#  '(2015–2023)',
# ...

# %%
try:
    run_time = driver.find_elements(By.XPATH,'//span[@class="runtime"]')
    Run_time= []
    for i in run_time:
        titles_ = i.text
        Run_time.append(titles_)
        
except Exception as e:
    print(f"An error occurred: {e}")

# %%
Run_time
# Out:
# ['55 min',
#  '51 min',
#  '44 min',
#  '60 min',
#  '43 min',
#  '59 min',
#  '45 min',
#  '41 min',
#  '43 min',
#  '42 min',
#  '70 min',
#  '22 min',
#  '60 min',
#  '88 min',
#  '44 min',
#  '44 min',
#  '43 min',
#  '60 min',
#  '45 min',
#  '4,393 min',
#  '44 min',
#  '44 min',
#  '43 min',
#  '41 min',
#  '22 min',
#  '60 min',
#  '49 min',
#  '54 min',
#  '5,280 min',
#  '4,576 min',
#  '44 min',
#  '49 min',
#  '45 min',
#  '43 min',
#  '42 min',
#  '60 min',
#  '42 min',
#  '62 min',
#  '56 min',
#  '5,378 min',
#  '23 min',
#  '42 min',
#  '25 min',
#  '3,804 min',
#  '1,455 min',
#  '60 min',
#  '1,755 min',
#  '46 min',
#  '22 min',
#  '45 min',
#  '55 min',
#  '45 min',
#  '51 min',
#  '55 min',
#  '44 min',
#  '44 min',
#  '60 min',
#  '22 min',
#  '43 min',
#  '43 min',
#  '59 min',
#  '5,445 min',
#  '45 min',
#  '2,109 min',
#  '41 min',
#  '7,788 min',
#  '43 min',
#  '42 min',
#  '42 min',
#  '44 min',
#  '70 min',
#  '55 min',
#  '22 min',
#  '42 min',
# ...

# %% [markdown]
# 8. QUESTION--> SOLUTION-->

# %%
driver = webdriver.Chrome()
url = "https://archive.ics.uci.edu/"
driver.get(url)

# %%
dataset = driver.find_element(By.XPATH,'//div[@class="flex flex-wrap justify-center gap-5"]/a[1]')

# %%
dataset.click()

# %%
try :
    dataset_name = driver.find_elements(By.XPATH,'//a[@class="link-hover link text-xl font-semibold"]')
    Dataset_name = []
    for i in dataset_name:
        titles_ = i.text
        Dataset_name.append(titles_)
        
except as Exception as e:
    print(f"An error occurred: {e}")

# %%
Dataset_name
# Out:
# ['Iris',
#  'Dry Bean Dataset',
#  'Heart Disease',
#  'Rice (Cammeo and Osmancik)',
#  'Adult',
#  'Raisin',
#  'Breast Cancer Wisconsin (Diagnostic)',
#  'Wine',
#  'Wine Quality',
#  'Diabetes']

# %%
try:
    dataset_information = driver.find_elements(By.XPATH,'//div[@class="col-span-3 flex items-center gap-2"]/span')
    Dataset_information_name = []
    for i in dataset_information:
        titles_ = i.text
        Dataset_information_name.append(titles_)
        
except asa Exception as e:
    print(f"An error occurred: {e}")

# %%
# Data Type , No. of instances , Task , No of feature

# %%
Dataset_information_name
# Out:
# ['Classification',
#  'Tabular',
#  '150 Instances',
#  '4 Features',
#  'Classification',
#  'Multivariate',
#  '13.61K Instances',
#  '16 Features',
#  'Classification',
#  'Multivariate',
#  '303 Instances',
#  '13 Features',
#  'Classification',
#  'Multivariate',
#  '3.81K Instances',
#  '7 Features',
#  'Classification',
#  'Multivariate',
#  '48.84K Instances',
#  '14 Features',
#  'Classification',
#  'Multivariate',
#  '900 Instances',
#  '8 Features',
#  'Classification',
#  'Multivariate',
#  '569 Instances',
#  '30 Features',
#  'Classification',
#  'Tabular',
#  '178 Instances',
#  '13 Features',
#  'Classification, Regression',
#  'Multivariate',
#  '4.9K Instances',
#  '12 Features',
#  'Classification',
#  'Multivariate, Time-Series',
#  '1 Instances',
#  '20 Features']

# %%
Table_body = driver.find_element(By.XPATH,'//tbody[@class="border"]')

# %%
data = []

# %%
try:
    for tr in Table_body.find_elements(By.XPATH, '//tr'):
        row = [item.text for item in tr.find_elements(By.XPATH, './/td')]
        data.append(row)
        
exception as e:
    print(f"An error occurred: {e}")

# %%
data
# Out:
# [[],
#  ['Biology', 'Real', '7/1/1988', '676.6K'],
#  [],
#  ['Biology', 'Integer, Real', '9/14/2020', '532.73K'],
#  [],
#  ['Health and Medicine', 'Categorical, Integer, Real', '7/1/1988', '474.49K'],
#  [],
#  ['Biology', 'Real', '10/6/2019', '465.39K'],
#  [],
#  ['Social Science', 'Categorical, Integer', '5/1/1996', '363.21K'],
#  [],
#  ['Biology', 'Real, Integer', '8/14/2023', '344.57K'],
#  [],
#  ['Health and Medicine', 'Real', '11/1/1995', '292.07K'],
#  [],
#  ['Physics and Chemistry', 'Integer, Real', '7/1/1991', '291.57K'],
#  [],
#  ['Business', 'Real', '10/7/2009', '241.15K'],
#  [],
#  ['Health and Medicine', 'Categorical, Integer', 'N/A', '223.61K']]

# %%
# Subject Type , Attribute Type , Year , Views
