# %% [markdown]
#  1. QUESTION-->  SOLUTION-->

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()  

try:
    driver.get("https://www.amazon.in/")
    search_box = driver.find_element(By.XPATH, '//input[@type="text"]')
    search_box.send_keys('guitar')

    search_button = driver.find_element(By.XPATH,'//input[@id="nav-search-submit-button"]')
    search_button.click()
except Exception as e:
    print(f"An error occurred: {e}")

# %% [markdown]
# 2.QUESTION--> SOLUTION-->

# %%
product_urls = driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')

# %%
product_images_url=[]
for element in product_urls[:60]:
    product_images = element.get_attribute("href")
    product_images_url.append(product_images)

# %%
product_images_url
# Out:
# ['https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo3MDQxNjM5MzEwNjgxMDQ3OjE3MDgxNDQyODA6c3BfYXRmOjMwMDAxNTUwODk1NDEzMjo6MDo6&url=%2FKadence-Frontier-Acoustic-Guitar-Strings%2Fdp%2FB01GDZ46AA%2Fref%3Dsr_1_1_sspa%3Fdib%3DeyJ2IjoiMSJ9.crxhhcuVe8Gag3-0mnCXJk7QJK_x0SlhaKCAQnkfSo-JyabtGbOlK7797mdecMrPfNE8NZT9LOGq-wHde9AUKqWrEUOJSMkKU992YX8E99JTzEdT0x6R21vZ_g0wHq-pkus2KjaM8qFD2iWaYDHYgL9E0DM5yHPSrg3Cx5-_xKMOZKvkFhtIcbx3RN0BR2grRGKU1l6dRdnaxPmK6ATMuTjM9k3Q4xYScc5VZRLFTuglo5_oXzSsc-Ts58_ZoqUD1JxFVHBD2OnZMPUrdobOvKFPuyV61VEOu2vrypA9cqQ.XDRmzmZjz0d2NuFG0XGAAgWJ8DRt-arS09tmYBzbMwI%26dib_tag%3Dse%26keywords%3Dguitar%26qid%3D1708144280%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1',
# ...

# %%
len(product_images_url)
# Out:
# 60

# %%
brand_name = driver.find_elements(By.XPATH,'//span[@class="a-size-base-plus a-color-base a-text-normal"]')
Brand_names = []
for i in brand_name[:60]:
    names = i.text
    Brand_names.append(names)

# %%
Brand_names
# Out:
# ['Kadence Frontier guitar with Online Guitar learning course , Wine Red Acoustic Guitar with Die Cast Keys, Set of Strings, Strap, Picks and Bag (Wine Red, Acoustic)',
#  'Kadence rosewood Guitar Frontier Series, Electric Acoustic Black Guitar With EQ, Die Cast Keys, Set Of Strings, Strap, Picks And Bag (Black EQ, Electric Acoustic)',
#  'Kadence Slowhand Premium Jumbo Semi Acoustic Guitar with Heavy Padded Bag, guitar cable, Pro Capo (Black Spruce Wood)',
#  'Henrix 38C 38 Inch Cutaway Acoustic Guitar With Dual Action Truss Rod, Gigbag, Picks, String Set, String Winder, Strap, Polishing Cloth & Ebook - Black',
#  'Intern INT-38C Right hand Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Black, small',
#  'Juârez Acoustic Guitar, 38 Inch Cutaway, 038C with Bag, Strings, Pick and Strap, Black',
#  'Kadence Frontier Series,Black Acoustic Guitar With Die Cast Keys Combo (Bag,strap,strings and 3 picks)',
# ...

# %%
len(Brand_names)
# Out:
# 60

# %%
price = driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
prices = []
for i in price[:60]:
    prices_ = i.text
    prices.append(prices_)

# %%
prices
# Out:
# ['9,999',
#  '9,999',
#  '4,499',
#  '5,499',
#  '9,999',
#  '3,099',
#  '1,999',
#  '2,199',
#  '4,999',
#  '4,499',
#  '5,499',
#  '2,495',
#  '',
#  '7,400',
#  '2,099',
#  '9,659',
#  '1,999',
#  '8,200',
#  '1,999',
#  '2,349',
#  '1,999',
#  '1,869',
#  '2,099',
#  '2,944',
#  '8,830',
#  '6,499',
#  '3,249',
#  '229',
#  '2,895',
#  '2,490',
#  '1,999',
#  '2,099',
#  '2,099',
#  '1,869',
#  '4,654',
#  '2,299',
#  '9,999',
#  '1,869',
#  '2,499',
#  '12,399',
#  '9,299',
#  '42,000',
#  '11,670',
#  '24,100',
#  '52,499',
#  '4,654',
#  '16,590',
#  '5,499',
#  '3,350',
#  '6,296',
#  '2,490',
#  '2,649',
#  '4,084',
#  '4,996',
#  '1,879',
#  '819',
#  '84,779',
#  '2,649',
#  '9,999',
#  '2,199']

# %%
len(prices)
# Out:
# 60

# %%
reviews = driver.find_elements(By.XPATH,'//span[@class="a-size-base s-underline-text"]')
Brand_reviews = []
for i in reviews[:60]:
    reviews_ = i.text
    Brand_reviews.append(reviews_)

# %%
Brand_reviews
# Out:
# ['3,101',
#  '1,164',
#  '653',
#  '2,169',
#  '14,217',
#  '21,449',
#  '3,101',
#  '3,101',
#  '1,164',
#  '110',
#  '',
#  '2,877',
#  '14,217',
#  '431',
#  '166',
#  '60',
#  '6,307',
#  '14,217',
#  '2,729',
#  '3',
#  '14,217',
#  '2,169',
#  '54',
#  '1',
#  '1',
#  '22',
#  '199',
#  '110',
#  '5,922',
#  '1,772',
#  '14,217',
#  '2',
#  '498',
#  '1,772',
#  '653',
#  '9',
#  '6',
#  '1,301',
#  '21',
#  '411',
#  '1,301',
#  '273',
#  '2',
#  '31',
#  '847',
#  '1,164',
#  '7',
#  '331',
#  '110',
#  '5,651',
#  '152',
#  '1',
#  '102',
#  '5,651',
#  '129',
#  '14,217',
#  '48',
#  '2,984',
#  '8',
#  '1']

# %%
len(Brand_reviews)
# Out:
# 60

# %%
expected_delivery = driver.find_elements(By.XPATH,'//span[@class="a-color-base a-text-bold"]')
Expected_delivery = []
for i in expected_delivery:
    delivery_ = i.text
    Expected_delivery.append(delivery_)

# %%
Expected_delivery
# Out:
# ['Thursday, 22 February',
#  'Thursday, 22 February',
#  'Tuesday, 20 February',
#  'Thursday, 22 February',
#  'Tuesday, 20 February',
#  'Thursday, 22 February',
#  'Tuesday, 20 February',
#  'Tuesday, 27 February',
#  'Thursday, 22 February',
#  'Wednesday, 28 February',
#  'Tuesday, 20 February',
#  'Wednesday, 21 February',
#  'Wednesday, 21 February',
#  'Thursday, 22 February',
#  'Tuesday, 20 February',
#  'Thursday, 22 February',
#  'Tuesday, 20 February',
#  'Wednesday, 21 February',
#  'Tuesday, 20 February',
#  'Monday, 19 February',
#  'Tuesday, 20 February',
#  'Wednesday, 21 February',
#  'Wednesday, 21 February',
#  'Thursday, 22 February',
#  'Thursday, 22 February',
#  'Thursday, 22 February',
#  'Thursday, 22 February',
#  'Tuesday, 20 February',
#  'Thursday, 22 February',
#  'Tuesday, 20 February',
#  'Thursday, 22 February',
#  'Tuesday, 20 February',
#  'Wednesday, 21 February',
#  'Wednesday, 21 February',
#  'Tuesday, 20 February',
# ...

# %%
len(Expected_delivery)
# Out:
# 60

# %%
import pandas as pd

# %%
df = pd.DataFrame({'product_images_url':product_images_url,'Brand_name' :Brand_names,'Brand_reviews':Brand_reviews,'prices':prices,'Expected_delivery':Expected_delivery})

# %%
df
# Out:
#                                    product_images_url  \
# 0   https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 1   https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 2   https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 3   https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 4   https://www.amazon.in/Intern-INT-38C-Acoustic-...
# 5   https://www.amazon.in/Juarez-Acoustic-Cutaway-...
# 6   https://www.amazon.in/Kadence-Frontier-Acousti...
# 7   https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 8   https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 9   https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 10  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 11  https://www.amazon.in/Yamaha-F280-Acoustic-Gui...
# 12  https://www.amazon.in/Intern-INT-38C-Acoustic-...
# 13  https://www.amazon.in/Yamaha-FS-100C-6-String-...
# 14  https://www.amazon.in/Medellin-Acoustic-Guitar...
# 15  https://www.amazon.in/YAMAHA-FS80C-CONCERT-CUT...
# ...

# %%
Next = driver.find_element(By.XPATH,'//a[@aria-label="Go to page 2"]')

# %%
Next.click()

# %%
product_urls = driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')

# %%
product_images_url=[]
for element in product_urls[:54]:
    product_images = element.get_attribute("href")
    product_images_url.append(product_images)

# %%
product_images_url
# Out:
# ['https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo3MTkzODUzNzU5NTYzMDQ3OjE3MDgxNDQ1MTM6c3BfYXRmX25leHQ6MzAwMTE4NzMxMjg4MDMyOjowOjo&url=%2FMOCKING-BIRD-Beginners-Instruments-Accessories%2Fdp%2FB0CMXDPFQV%2Fref%3Dsr_1_49_sspa%3Fdib%3DeyJ2IjoiMSJ9.RNfouDVILev7OJ36oQd1NsWfPRH3ggZyw85CX4ZIdxcf9YA2glO686oPpXUiXfFfGvjNb4RiVaKV1fWfPf5jL7w7r26-kr8ZsZxv76lkbyQ.9aBwV0MYVExWiAU5-k_Sj8tG5zjCVM-CR_LZgXMqq0s%26dib_tag%3Dse%26keywords%3Dguitar%26qid%3D1708144513%26sr%3D8-49-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGZfbmV4dA%26psc%3D1',
# ...

# %%
len(product_images_url)
# Out:
# 54

# %%
brand_name = driver.find_elements(By.XPATH,'//span[@class="a-size-base-plus a-color-base a-text-normal"]')
Brand_names = []
for i in brand_name[:54]:
    names = i.text
    Brand_names.append(names)

# %%
Brand_names
# Out:
# ['MOCKING BIRD 38c Acoustic Guitar for Beginners Musical Instruments For Adults premium kit wood curved cutaway design Guitar Accessories with string & 5 picks & bag for beige (Beige)',
#  'Henrix 38C PRO 38 Inch Cutaway Acoustic Guitar With with Die-cast Tuners, Dual-action Truss Rod, Gig-Bag, Picks, String set, String Winder, Strap & Polishing Cloth - Black',
#  'Kaspar 10C Lindenwood Acoustic guitar 38 Inches Cutaway guitar & Truss Rod Guitar for beginers & students (Blue)',
#  'Kaspar 10C Lindenwood Acoustic guitar 38 Inches Cutaway guitar & Truss Rod Guitar with floor stand or wall mount for beginers & students (natural)',
#  'Fender Dreadnought Acoustic Guitar FA-125 Black Right-Handed 971210706',
#  'Cort Acoustic Guitar with Cutaway Electronics AF515CE Open Pore',
#  'Juârez Acoustic Guitar, 38 Inch Cutaway, JRZ38C with Bag, Strings, Pick and Strap, Red',
#  'Epiphone AJ-220S Acoustic Guitar, Natural (EA22NANH1)',
# ...

# %%
len(Brand_names)
# Out:
# 54

# %%
price = driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
prices = []
for i in price[:54]:
    prices_ = i.text
    prices.append(prices_)

# %%
prices
# Out:
# ['1,899',
#  '1,899',
#  '3,249',
#  '3,599',
#  '4,499',
#  '4,899',
#  '13,984',
#  '14,130',
#  '2,609',
#  '30,875',
#  '1,999',
#  '2,049',
#  '8,690',
#  '7,829',
#  '17,999',
#  '20,109',
#  '4,581',
#  '4,999',
#  '20,389',
#  '229',
#  '695',
#  '45,999.',
#  '6,739',
#  '8,999',
#  '8,999',
#  '9,999',
#  '3,699',
#  '4,169',
#  '12,999',
#  '2,099',
#  '10,999',
#  '3,699',
#  '7,999',
#  '425',
#  '7,400',
#  '2,909',
#  '5,979',
#  '11,570',
#  '3,419',
#  '2,649',
#  '14,499',
#  '4,370',
#  '2,799',
#  '27,990',
#  '12,999',
#  '3,179',
#  '9,990',
#  '2,489',
#  '6,899',
#  '697',
#  '11,099',
#  '2,895',
#  '8,091',
#  '3,249']

# %%
len(prices)
# Out:
# 54

# %%
reviews = driver.find_elements(By.XPATH,'//span[@class="a-size-base s-underline-text"]')
Brand_reviews = []
for i in reviews:
    reviews_ = i.text
    Brand_reviews.append(reviews_)

# %%
Brand_reviews
# Out:
# ['1',
#  '2,169',
#  '6',
#  '5',
#  '1,429',
#  '86',
#  '1,772',
#  '2,663',
#  '223',
#  '306',
#  '96',
#  '746',
#  '335',
#  '510',
#  '22',
#  '85',
#  '8',
#  '653',
#  '2',
#  '38',
#  '1',
#  '1,772',
#  '11',
#  '3',
#  '9',
#  '167',
#  '82',
#  '67',
#  '10',
#  '110',
#  '23',
#  '794',
#  '460',
#  '39',
#  '5,651',
#  '158',
#  '3',
#  '83',
#  '112',
#  '215',
#  '1,381',
#  '1',
#  '199',
#  '303',
#  '1',
#  '26',
#  '152',
#  '38',
#  '1,299',
#  '2',
#  '1',
#  '3',
#  '23',
#  '42']

# %%
len(Brand_reviews)
# Out:
# 54

# %%
expected_delivery = driver.find_elements(By.XPATH,'//span[@class="a-color-base a-text-bold"]')
Expected_delivery = []
for i in expected_delivery[:54]:
    delivery_ = i.text
    Expected_delivery.append(delivery_)

# %%
Expected_delivery
# Out:
# ['Monday, 19 February',
#  'Thursday, 22 February',
#  'Wednesday, 21 February',
#  'Wednesday, 21 February',
#  'Thursday, 22 February',
#  'Tuesday, 20 February',
#  'Friday, 23 February',
#  'Tuesday, 20 February',
#  'Thursday, 22 February',
#  'Thursday, 22 February',
#  'Wednesday, 21 February',
#  'Friday, 23 February',
#  'Tuesday, 20 February',
#  'Tuesday, 20 February',
#  'Wednesday, 21 February',
#  'Thursday, 22 February',
#  'Tuesday, 20 February',
#  'Tuesday, 20 February',
#  'Monday, 19 February',
#  'Thursday, 22 February',
#  'Thursday, 22 February',
#  'Thursday, 22 February',
#  'Thursday, 22 February',
#  'Wednesday, 21 February',
#  'Tuesday, 20 February',
#  'Thursday, 22 February',
#  'Friday, 23 February',
#  'Tuesday, 20 February',
#  'Thursday, 22 February',
#  'Tuesday, 20 February',
#  'Monday, 19 February',
#  'Thursday, 22 February',
#  'Tuesday, 20 February',
#  'Friday, 23 February',
#  'Saturday, 24 February',
#  'Tuesday, 20 February',
# ...

# %%
len(Expected_delivery)
# Out:
# 54

# %%
df_1 = pd.DataFrame({'product_images_url':product_images_url,'Brand_name' :Brand_names,'Brand_reviews':Brand_reviews,'prices':prices,'Expected_delivery':Expected_delivery})

# %%
df_1
# Out:
#                                    product_images_url  \
# 0   https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 1   https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 2   https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 3   https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 4   https://www.amazon.in/Fender-FA-125-Dreadnough...
# 5   https://www.amazon.in/Cort-AF515CE-6-String-El...
# 6   https://www.amazon.in/JUAREZ-JRZ38C-Handed-Aco...
# 7   https://www.amazon.in/Epiphone-AJ-220S-Acousti...
# 8   https://www.amazon.in/Intern-INT-38C-BK-G-Guit...
# 9   https://www.amazon.in/Intern-INT-38C-Natural-A...
# 10  https://www.amazon.in/Yamaha-Acoustic-Tobacco-...
# 11  https://www.amazon.in/Yamaha-Acoustic-Guitar-T...
# 12  https://www.amazon.in/Fender-60S-Dreadnought-A...
# 13  https://www.amazon.in/ORANGEWOOD-OLIVER-MAHOGA...
# 14  https://www.amazon.in/Rosewood-Fretboard-Acous...
# 15  https://www.amazon.in/Kadence-Frontier-Acousti...
# ...

# %%
Next = driver.find_element(By.XPATH,'//a[@href="/s?k=guitar&page=3&qid=1708144513&ref=sr_pg_3"]')

# %%
Next.click()

# %%
product_urls = driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
product_images_url=[]
for element in product_urls[:54]:
    product_images = element.get_attribute("href")
    product_images_url.append(product_images)

# %%
product_images_url
# Out:
# ['https://www.amazon.in/sspa/click?ie=UTF8&spc=MTozNTM3NzYxMzQzODk0MDQ3OjE3MDgxNDQ5NTA6c3BfYXRmX25leHQ6MzAwMTE4NzMxMjg3NzMyOjowOjo&url=%2FMOCKING-BIRD-Beginners-Instruments-Accessories%2Fdp%2FB0CMXHQH75%2Fref%3Dsr_1_97_sspa%3Fdib%3DeyJ2IjoiMSJ9.-TWTZSOctPgU5dgRG9-eQOpnnSd7Mz9vcAwxb4TUgc8FDqvVlCIc1FnHaKf-PBG51UumfPi3U2LBFFhOZkJZ7v6jnRT5JqvxN_3ARdB6kRSxFYqnNOVZoUWoDEjj-hsULe2HAWKFw8QehJ8lt1yXDLWMfePnqtD1N4P9v1t1868lmFRysDjef4XPBmAqRYJrNKz6YaIKbX8dQroBW2dGECZ7g4HuyGeFjdcVv00Uk_4br1NWYS8iXBnwkhxuFrZqh65iIdt__grFWaLBarajVnqGv1L0NgKdYjKFX663tSw.xefi6CcgSRS-awCbWkwW4plHl1k7M1y40-AcBFKn62o%26dib_tag%3Dse%26keywords%3Dguitar%26qid%3D1708144950%26sr%3D8-97-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGZfbmV4dA%26psc%3D1',
# ...

# %%
len(product_images_url)
# Out:
# 54

# %%
brand_name = driver.find_elements(By.XPATH,'//span[@class="a-size-base-plus a-color-base a-text-normal"]')
Brand_names = []
for i in brand_name[:54]:
    names = i.text
    Brand_names.append(names)

# %%
Brand_names
# Out:
# ['MOCKING BIRD 38c Acoustic Guitar for Beginners Musical Instruments For Adults premium kit wood curved cutaway design Guitar Accessories with string & 5 picks & bag for beige (Red)',
#  'BLUEBERRY R-40, Sapele Wood Acoustic Guitar Kit with Inbuilt Truss Rod, Bag, Strap, One Pack Strings And Picks - 40 Inch (Classic Brown)',
#  'Henrix 38C PRO 38 Inch Cutaway Acoustic Guitar With with Die-cast Tuners, Dual-action Truss Rod, Gig-Bag, Picks, String set, String Winder, Strap & Polishing Cloth - Red Burst',
#  'Kaspar 10C Lindenwood Acoustic guitar 38 Inches Cutaway guitar & Truss Rod Guitar for beginers & students (Sunburst)',
#  'Intern Int-38c Sunburst Linden Wood Acoustic Guitar Kit with Carry Bag and Picks',
#  'Donner Silent Guitar, Mahogany',
#  'Yamaha FSX80C Semi acoustic cutaway guitar (natural)',
#  'Medellin 38" Blue Acoustic Guitar premium wood with free online learning course, Set Of Strings, Strap, Bag and 3 Picks',
# ...

# %%
len(Brand_names)
# Out:
# 54

# %%
price = driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
prices = []
for i in price[:54]:
    prices_ = i.text
    prices.append(prices_)

# %%
prices
# Out:
# ['1,899',
#  '1,899',
#  '3,249',
#  '4,795',
#  '3,599',
#  '4,499',
#  '24,505',
#  '12,679',
#  '45,999.',
#  '2,199',
#  '8,649',
#  '3,649',
#  '249',
#  '6,899',
#  '9,500',
#  '14,440',
#  '729',
#  '16,499',
#  '799',
#  '4,009',
#  '7,199',
#  '2,395',
#  '3,290',
#  '4,590',
#  '2,495',
#  '2,889',
#  '6,689',
#  '5,234',
#  '64,434',
#  '7,999',
#  '2,649',
#  '13,300',
#  '11,499',
#  '15,599',
#  '34,189',
#  '11,790',
#  '3,299',
#  '235',
#  '3,899',
#  '24,549',
#  '7,829',
#  '6,499',
#  '23,900',
#  '6,059',
#  '11,099',
#  '3,290',
#  '429',
#  '800',
#  '4,290',
#  '3,039',
#  '11,259',
#  '8,999',
#  '2,699',
#  '6,509']

# %%
len(prices)
# Out:
# 54

# %%
reviews = driver.find_elements(By.XPATH,'//span[@class="a-size-base s-underline-text"]')
Brand_reviews = []
for i in reviews[:54]:
    reviews_ = i.text
    Brand_reviews.append(reviews_)

# %%
Brand_reviews
# Out:
# ['1',
#  '39',
#  '2,169',
#  '2,663',
#  '194',
#  '47',
#  '660',
#  '44',
#  '4',
#  '212',
#  '1,381',
#  '1,884',
#  '3',
#  '4,493',
#  '1,027',
#  '4',
#  '33',
#  '9',
#  '3',
#  '110',
#  '199',
#  '7',
#  '57',
#  '610',
#  '5,651',
#  '57',
#  '135',
#  '203',
#  '22',
#  '159',
#  '48',
#  '1',
#  '8,042',
#  '2',
#  '135',
#  '903',
#  '2',
#  '206',
#  '5',
#  '45',
#  '2',
#  '2,585',
#  '69',
#  '57',
#  '41',
#  '1',
#  '12',
#  '10',
#  '418',
#  '42',
#  '43',
#  '3',
#  '2',
#  '42']

# %%
Brand_reviews
# Out:
# ['1',
#  '39',
#  '2,169',
#  '2,663',
#  '194',
#  '47',
#  '660',
#  '44',
#  '4',
#  '212',
#  '1,381',
#  '1,884',
#  '3',
#  '4,493',
#  '1,027',
#  '4',
#  '33',
#  '9',
#  '3',
#  '110',
#  '199',
#  '7',
#  '57',
#  '610',
#  '5,651',
#  '57',
#  '135',
#  '203',
#  '22',
#  '159',
#  '48',
#  '1',
#  '8,042',
#  '2',
#  '135',
#  '903',
#  '2',
#  '206',
#  '5',
#  '45',
#  '2',
#  '2,585',
#  '69',
#  '57',
#  '41',
#  '1',
#  '12',
#  '10',
#  '418',
#  '42',
#  '43',
#  '3',
#  '2',
#  '42']

# %%
len(Brand_reviews)
# Out:
# 54

# %%
expected_delivery = driver.find_elements(By.XPATH,'//span[@class="a-color-base a-text-bold"]')
Expected_delivery = []
for i in expected_delivery[:54]:
    delivery_ = i.text
    Expected_delivery.append(delivery_)

# %%
Expected_delivery
# Out:
# ['Monday, 19 February',
#  'Wednesday, 21 February',
#  'Wednesday, 21 February',
#  'Wednesday, 21 February',
#  'Sunday, 25 February',
#  'Wednesday, 21 February',
#  'Thursday, 22 February',
#  'Wednesday, 21 February',
#  'Wednesday, 21 February',
#  'Monday, 19 February',
#  'Thursday, 22 February',
#  'Tuesday, 20 February',
#  'Thursday, 22 February',
#  'Monday, 19 February',
#  'Thursday, 22 February',
#  'Monday, 19 February',
#  'Thursday, 22 February',
#  'Thursday, 22 February',
#  'Tuesday, 20 February',
#  'Wednesday, 21 February',
#  'Wednesday, 21 February',
#  'Wednesday, 21 February',
#  'Wednesday, 21 February',
#  'Thursday, 22 February',
#  'Monday, 19 February',
#  'Tuesday, 20 February',
#  'Thursday, 22 February',
#  'Saturday, 24 February',
#  'Tuesday, 20 February',
#  'Thursday, 22 February',
#  'Thursday, 22 February',
#  'Friday, 23 February',
#  'Monday, 19 February',
#  'Monday, 19 February',
#  'Wednesday, 21 February',
#  'Thursday, 22 February',
# ...

# %%
len(Expected_delivery)
# Out:
# 54

# %%
df_2 = pd.DataFrame({'product_images_url':product_images_url,'Brand_name' :Brand_names,'Brand_reviews':Brand_reviews,'prices':prices,'Expected_delivery':Expected_delivery})

# %%
df_2
# Out:
#                                    product_images_url  \
# 0   https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 1   https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 2   https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 3   https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 4   https://www.amazon.in/Intern-INT-38C-Sunburst-...
# 5   https://www.amazon.in/Donner-Silent-Guitar-Mah...
# 6   https://www.amazon.in/Yamaha-FSX80C-Acoustic-C...
# 7   https://www.amazon.in/Medellin-MED-BLU-C-Linde...
# 8   https://www.amazon.in/Yamaha-F280-Acoustic-Dre...
# 9   https://www.amazon.in/PS-Signature-41inch-Acou...
# 10  https://www.amazon.in/Kadence-Acoustic-Guitar-...
# 11  https://www.amazon.in/Kadence-Frontier-Acousti...
# 12  https://www.amazon.in/Yamaha-F310-6-Strings-Ac...
# 13  https://www.amazon.in/Cort-AC120CEOP-Classical...
# 14  https://www.amazon.in/DAddario-EJ26-Acoustic-C...
# 15  https://www.amazon.in/Acoustic-Beginner-Acusti...
# ...

# %%
Data_frame = pd.concat([df,df_1,df_2], ignore_index = True)

# %%
Data_frame
# Out:
#                                     product_images_url  \
# 0    https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 1    https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 2    https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 3    https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 4    https://www.amazon.in/Intern-INT-38C-Acoustic-...
# ..                                                 ...
# 163  https://www.amazon.in/Yamaha-FX280-acoustic-Dr...
# 164  https://www.amazon.in/Kadence-Slowhand-Premium...
# 165  https://www.amazon.in/Belear-I-280-WBR-Action-...
# 166  https://www.amazon.in/JUAREZ-Arpeggio-Semi-Aco...
# 167  https://www.amazon.in/Yamaha-Electric-Acoustic...
#
#                                             Brand_name Brand_reviews  prices  \
# 0    Kadence Frontier guitar with Online Guitar lea...         3,101   9,999
# 1    Kadence rosewood Guitar Frontier Series, Elect...         1,164   9,999
# ...

# %%
# Saving a data frame to csv file

# %%
Data_frame.to_csv('file1.csv')

# %% [markdown]
# 3. QUESTION--> SOLUTION-->

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
 
try:
    driver = webdriver.Chrome()

    driver.get("https://images.google.com/")
    
    search_bar = driver.find_element(By.XPATH,'//textarea[@class="gLFyf"]')

    search_bar.send_keys('ears')

    search_button = driver.find_element(By.XPATH,'//span[@class="z1asCe MZy1Rb"]')
    
    search_button.submit()
    
    driver.implicitly_wait(10)
    
    IMAGES = driver.find_elements(By.XPATH,'//div[@class="fR600b islir"]/img')
    

    for i in IMAGES[:10]:
        img_url = i.get_attribute('src')
        print(img_url)
        

except NoSuchElementException as e:
        print(f"Error: {e}")
        
finally:
    
    driver.quit()
# Out:
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...

# %%
try:
    driver = webdriver.Chrome()

    driver.get("https://images.google.com/")
    
    search_bar = driver.find_element(By.XPATH,'//textarea[@class="gLFyf"]')

    search_bar.send_keys('Machine Learning')

    search_button = driver.find_element(By.XPATH,'//span[@class="z1asCe MZy1Rb"]')
    
    search_button.submit()
    
    driver.implicitly_wait(10)
    
    IMAGES = driver.find_elements(By.XPATH,'//div[@class="fR600b islir"]/img')
    

    for i in IMAGES[:5]:
        img_url = i.get_attribute('src')
        print(img_url)
        

except NoSuchElementException as e:
        print(f"Error: {e}")
        
finally:
    
    driver.quit()
# Out:
# Error sending stats to Plausible: error sending request for url (https://plausible.io/api/event): error trying to connect: dns error: No such host is known. (os error 11001)
# data:image/png;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...

# %%
try:
    driver = webdriver.Chrome()

    driver.get("https://images.google.com/")
    
    search_bar = driver.find_element(By.XPATH,'//textarea[@class="gLFyf"]')

    search_bar.send_keys('Guitar')

    search_button = driver.find_element(By.XPATH,'//span[@class="z1asCe MZy1Rb"]')
    
    search_button.submit()
    
    driver.implicitly_wait(10)
    
    IMAGES = driver.find_elements(By.XPATH,'//div[@class="fR600b islir"]/img')
    

    for i in IMAGES[:5]:
        img_url = i.get_attribute('src')
        print(img_url)
        

except NoSuchElementException as e:
        print(f"Error: {e}")
        
finally:
    
    driver.quit()
# Out:
# There was an error managing chromedriver (error sending request for url (https://googlechromelabs.github.io/chrome-for-testing/known-good-versions-with-downloads.json): error trying to connect: dns error: No such host is known. (os error 11001)); using driver found in the cache
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...

# %%
try:
    driver = webdriver.Chrome()

    driver.get("https://images.google.com/")
    
    search_bar = driver.find_element(By.XPATH,'//textarea[@class="gLFyf"]')

    search_bar.send_keys('Cakes')

    search_button = driver.find_element(By.XPATH,'//span[@class="z1asCe MZy1Rb"]')
    
    search_button.submit()
    
    driver.implicitly_wait(10)
    
    IMAGES = driver.find_elements(By.XPATH,'//div[@class="fR600b islir"]/img')
    

    for i in IMAGES[:5]:
        img_url = i.get_attribute('src')
        print(img_url)
        

except NoSuchElementException as e:
        print(f"Error: {e}")
        
finally:
    
    driver.quit()
# Out:
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...

# %% [markdown]
# 4. QUESTION--> SOLUTION-->

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()

try:
    URL = driver.get("https://www.flipkart.com/search?q=one%20plus%20nord&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off")
    brand_name = driver.find_elements(By.XPATH,'//div[@class="_4rR01T"]')

    Brand_names = []
    for i in brand_name:
        brand_ = i.text
        Brand_names.append(brand_)

except Exception as e:
    print(f"error occured as : {e}")

# %%
Brand_names
# Out:
# ['OnePlus Nord CE 3 Lite 5G (Pastel Lime, 256 GB)',
#  'OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 256 GB)',
#  'OnePlus Nord CE 3 Lite 5G (Pastel Lime, 128 GB)',
#  'OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 128 GB)',
#  'OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 256 GB)',
#  'OnePlus Nord CE 3 Lite 5G (Pastel lime, 256 GB)',
#  'OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)',
#  'OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 128 GB)',
#  'OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)',
#  'OnePlus Nord CE 3 Lite 5G (Pastel Lime, 128 GB)',
#  'OnePlus Nord CE3 5G (Aqua Surge, 128 GB)',
#  'OnePlus Nord 3 5G (Misty Green, 128 GB)',
#  'OnePlus Nord CE3 5G (Grey Shimmer, 128 GB)',
#  'OnePlus Nord CE 3 Lite 5G (Pastel Lime, 256 GB)',
#  'OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 256 GB)',
#  'OnePlus Nord 3 5G (Tempest Gray, 256 GB)',
#  'OnePlus Nord 3 5G (Tempest Gray, 128 GB)',
#  'OnePlus Nord 3 5G (Misty Green, 256 GB)',
#  'OnePlus Nord CE 2 5G (Bahama Blue, 128 GB)',
# ...

# %%
len(Brand_names)
# Out:
# 24

# %%
rating = driver.find_elements(By.XPATH,'//div[@class="_3LWZlK"]')

Brand_rating = []
for i in rating[:24]:
    rating_ = i.text
    Brand_rating.append(rating_)

# %%
Brand_rating
# Out:
# ['4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.4',
#  '4.3',
#  '4']

# %%
len(Brand_rating)
# Out:
# 24

# %%
description = driver.find_elements(By.XPATH,'//ul[@class="_1xgFaf"]/li')

product_description = []
for i in description[:24]:
    details_ = i.text
    product_description.append(details_)

# %%
product_description
# Out:
# ['8 GB RAM | 256 GB ROM',
#  '17.07 cm (6.72 inch) Display',
#  '108MP Rear Camera',
#  '5000 mAh Battery',
#  'Domestic Warranty of 12 months on phone & 6 months on accessories',
#  '8 GB RAM | 256 GB ROM',
#  '17.07 cm (6.72 inch) Display',
#  '108MP Rear Camera',
#  '5000 mAh Battery',
#  'Domestic Warranty of 12 months on phone & 6 months on accessories',
#  '8 GB RAM | 128 GB ROM',
#  '17.07 cm (6.72 inch) Display',
#  '108MP Rear Camera',
#  '5000 mAh Battery',
#  'Domestic Warranty of 12 months on phone & 6 months on accessories',
#  '8 GB RAM | 128 GB ROM',
#  '17.07 cm (6.72 inch) Display',
#  '108MP Rear Camera',
#  '5000 mAh Battery',
#  'Domestic Warranty of 12 months on phone & 6 months on accessories',
#  '8 GB RAM | 256 GB ROM',
#  '17.07 cm (6.72 inch) Display',
#  '108MP Rear Camera',
#  '5000 mAh Battery']

# %%
len(product_description)
# Out:
# 24

# %%
price = driver.find_elements(By.XPATH,'//div[@class="_30jeq3 _1_WHN1"]')

Brand_price = []
for i in price:
    price_ = i.text
    Brand_price.append(price_)

# %%
Brand_price
# Out:
# ['₹19,895',
#  '₹19,770',
#  '₹18,172',
#  '₹18,204',
#  '₹20,117',
#  '₹19,929',
#  '₹18,140',
#  '₹18,930',
#  '₹17,657',
#  '₹18,725',
#  '₹24,566',
#  '₹29,900',
#  '₹24,554',
#  '₹20,790',
#  '₹21,275',
#  '₹37,999',
#  '₹28,680',
#  '₹37,890',
#  '₹21,780',
#  '₹21,395',
#  '₹22,495',
#  '₹18,829',
#  '₹28,990',
#  '₹22,989']

# %%
len(Brand_price)
# Out:
# 24

# %%
df_1 = pd.DataFrame({'Brand_name' :Brand_names,'Brand_rating':Brand_rating,'prices':Brand_price,'Product_description':product_description})df_

# %%
df_1
# Out:
#                                            Brand_name Brand_rating   prices  \
# 0     OnePlus Nord CE 3 Lite 5G (Pastel Lime, 256 GB)          4.4  ₹19,895
# 1   OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 256...          4.4  ₹19,770
# 2     OnePlus Nord CE 3 Lite 5G (Pastel Lime, 128 GB)          4.4  ₹18,172
# 3   OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 128...          4.4  ₹18,204
# 4   OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 256...          4.4  ₹20,117
# 5     OnePlus Nord CE 3 Lite 5G (Pastel lime, 256 GB)          4.4  ₹19,929
# 6       OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)          4.4  ₹18,140
# 7   OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 128...          4.4  ₹18,930
# 8      OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)          4.4  ₹17,657
# 9     OnePlus Nord CE 3 Lite 5G (Pastel Lime, 128 GB)          4.4  ₹18,725
# 10           OnePlus Nord CE3 5G (Aqua Surge, 128 GB)          4.4  ₹24,566
# ...

# %%
#Saved a dataframe into a csvfile named file2.csv

# %%
df_1.to_csv('file2.csv')

# %% [markdown]
# 5.QUESTION--> SOLUTION-->

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()

try:
    
    driver.get("https://www.google.com/maps/place/23%C2%B010'45.3%22N+75%C2%B047'20.3%22E/@23.1792398,75.7864007,17z/data=!3m1!4b1!4m4!3m3!8m2!3d23.1792349!4d75.7889756?entry=ttu")
    
    coordinates_element = driver.find_element(By.XPATH, '//h1[@class="DUwDvf lfPIob"]/span[1]')
        
    coordinates_text = coordinates_element.text
    
    print(coordinates_text)     

        

except Exception as e:
    print(f"An error occurred: {e}")

finally:
        driver.quit()

# %%
coordinates_element
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="0723455e6841f50d98563f0465c90d24", element="4563593FB3D7E8C59F556CF0763B73AF_element_20")>

# %%
coordinates_text
# Out:
# ''

# %% [markdown]
# 6. QUESTION --> SOLUTION-->

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()

try:
    
    URL = driver.get("https://www.digit.in/top-products/best-amd-gaming-laptops-with-nvidia-geforce-rtx-3050-4073.html")
    
    lap_names = driver.find_elements(By.XPATH,'//h3[@class="font130 mt0 mb10 mobilesblockdisplay "]/a')
    
    laptop_names = []
    for i in lap_names:
        names =  print(i.text)
        laptop_names.append(names)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Lenovo IdeaPad Gaming 3 82K200X3IN Ryzen 7-5800H (2022)
# Dell New G15-5515 D560805WIN9W Ryzen 5-5600H (2022)
# HP Pavilion Gaming 15-ec2145AX Ryzen 5-5600H (2022)
# Lenovo IdeaPad Gaming 3 15ACH6 Ryzen 5-5600H (2021)

# %%
Available_details = driver.find_elements(By.XPATH,'//span[@class="meta_v_value"]')

product_details = []
for i in Available_details:
    details = print(i.text)
    product_details.append(details)
# Out:
# Windows 11 Home
# 15.6
# 1920 x 1080
# 5th Gen AMD Ryzen 7-5800
# Windows 10
# 15.6
# 1920 x 1080
# AMD Ryzen 5-5600H
# Windows 11 Home
# 15.6
# 1920 x 1080
# AMD Ryzen 5 5600H
# Windows 11 Home
# 15.6
# 1920 x 1080
# AMD Ryzen 5-5600H

# %% [markdown]
# 7. QUESTION--> SOLUTION-->

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()

try:
    URL = driver.get("https://www.forbes.com/billionaires/")
    table_body = driver.find_element(By.XPATH,'//div[@class="TableRow_rowContainer__IC1Tv"]')
    data = []

    for tr in table_body.find_elements(By.XPATH, '//div[@class="TableRow_row__L-0Km TableRow_activeRow__g4oSF"]'):
        row_1 = [item.text for item in tr.find_elements(By.XPATH, './/div[@class="TableRow_cell__db-hv Table_cell__houv9"]')]
        data.append(row_1)

except Exception as e:
    print(f"error occured as: {e}")
# Out:
# Error sending stats to Plausible: error sending request for url (https://plausible.io/api/event): operation timed out

# %%
data
# Out:
# [['1', 'Bernard Arnault & family', '$211 B', '74', 'France', 'LVMH', '']]

# %%
for tr in table_body.find_elements(By.XPATH, '//div[@class="TableRow_row__L-0Km"]'):
    row = [item.text for item in tr.find_elements(By.XPATH, './/div[@class="TableRow_cell__db-hv Table_cell__houv9"]')]
    data.append(row)

# %%
data
# Out:
# [['1', 'Bernard Arnault & family', '$211 B', '74', 'France', 'LVMH', ''],
#  ['2', 'Elon Musk', '$180 B', '51', 'United States', 'Tesla, SpaceX', ''],
#  ['3', 'Jeff Bezos', '$114 B', '59', 'United States', 'Amazon', ''],
#  ['4', 'Larry Ellison', '$107 B', '78', 'United States', 'Oracle', ''],
#  ['5',
#   'Warren Buffett',
#   '$106 B',
#   '92',
#   'United States',
#   'Berkshire Hathaway',
#   ''],
#  ['6', 'Bill Gates', '$104 B', '67', 'United States', 'Microsoft', ''],
#  ['7',
#   'Michael Bloomberg',
#   '$94.5 B',
#   '81',
#   'United States',
#   'Bloomberg LP',
#   ''],
#  ['8', 'Carlos Slim Helu & family', '$93 B', '83', 'Mexico', 'Telecom', ''],
#  ['9', 'Mukesh Ambani', '$83.4 B', '65', 'India', 'Diversified', ''],
#  ['10', 'Steve Ballmer', '$80.7 B', '67', 'United States', 'Microsoft', ''],
#  ['11',
#   'Francoise Bettencourt Meyers & family',
#   '$80.5 B',
#   '69',
#   'France',
#   "L'Oréal",
#   ''],
# ...

# %% [markdown]
# 8.QUESTION--> SOLUTION-->

# %% [markdown]
# 9. QUESTION--> SOLUTION-->

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()

try:
    URL = driver.get("https://www.hostelworld.com/pwa/wds/s?q=London,%20England&country=London&city=London&type=city&id=3&from=2024-02-17&to=2024-02-20&guests=2&page=1")

    hostel = driver.find_elements(By.XPATH,'//div[@class="property-name"]')


    hostel_names = []
    for i in hostel:
        names = i.text
        hostel_names.append(names)

except Exception as e: 
    print(f"error occured as : {e}")

# %%
hostel
# Out:
# []

# %%
rating = driver.find_elements(By.XPATH, '//span[@class="number"]')

hostel_rating = []
for i in rating:
    rating_ = i.text
    hostel_rating.append(rating_)

# %%
hostel_rating
# Out:
# ['9.1',
#  '8.8',
#  '7.8',
#  '9.1',
#  '8.8',
#  '7.8',
#  '8.9',
#  '9.5',
#  '9.6',
#  '7.5',
#  '9.6',
#  '8.2',
#  '7.3',
#  '8.4',
#  '7.7',
#  '8.0',
#  '7.1',
#  '7.6',
#  '6.9',
#  '7.9',
#  '7.8',
#  '9.0',
#  '7.5',
#  '9.1',
#  '8.7',
#  '8.8',
#  '8.1',
#  '8.4',
#  '8.2',
#  '8.5',
#  '8.0',
#  '7.2',
#  '7.5']

# %%
fullreview = driver.find_elements(By.XPATH, '//span[@class="left-margin"]')

full_review = []
for i in fullreview:
    review_ = i.text
    full_review.append(review_)

# %%
full_review
# Out:
# ['(15924)',
#  '(15982)',
#  '(12880)',
#  '(2151)',
#  '(1130)',
#  '(2606)',
#  '(8090)',
#  '(151)',
#  '(12332)',
#  '(5284)',
#  '(9458)',
#  '(4180)',
#  '(522)',
#  '(5207)',
#  '(10213)',
#  '(1787)',
#  '(4304)',
#  '(6803)',
#  '(4704)',
#  '(3692)',
#  '(320)',
#  '(873)',
#  '(122)',
#  '(4568)',
#  '(3145)',
#  '(2978)',
#  '(6596)',
#  '(3605)',
#  '(15100)',
#  '(4391)']

# %%
review = driver.find_elements(By.XPATH, '//span[@class="keyword"]')

hostel_review = []
for i in review:
    review_ = i.text
    hostel_review.append(review_)

# %%
hostel_review
# Out:
# ['Superb',
#  'Fabulous',
#  'Very Good',
#  'Superb',
#  'Fabulous',
#  'Very Good',
#  'Fabulous',
#  'Superb',
#  'Superb',
#  'Very Good',
#  'Superb',
#  'Fabulous',
#  'Very Good',
#  'Fabulous',
#  'Very Good',
#  'Fabulous',
#  'Very Good',
#  'Very Good',
#  'Good',
#  'Very Good',
#  'Very Good',
#  'Superb',
#  'Very Good',
#  'Superb',
#  'Fabulous',
#  'Fabulous',
#  'Fabulous',
#  'Fabulous',
#  'Fabulous',
#  'Fabulous',
#  'Fabulous',
#  'Very Good',
#  'Very Good']

# %%
distance = driver.find_elements(By.XPATH, '//span[@class="distance-description"]')

distance_from_city = []
for i in distance:
    distance_ = i.text
    distance_from_city.append(distance_)

# %%
distance_from_city
# Out:
# ['- 3.6km from city centre',
#  '- 6.5km from city centre',
#  '- 1.8km from city centre',
#  '- 6.1km from city centre',
#  '- 5.4km from city centre',
#  '- 5.5km from city centre',
#  '- 3km from city centre',
#  '- 0.7km from city centre',
#  '- 4.3km from city centre',
#  '- 1.7km from city centre',
#  '- 2.2km from city centre',
#  '- 9km from city centre',
#  '- 3.2km from city centre',
#  '- 10km from city centre',
#  '- 2.6km from city centre',
#  '- 5.8km from city centre',
#  '- 0.2km from city centre',
#  '- 5km from city centre',
#  '- 2.1km from city centre',
#  '- 5.7km from city centre',
#  '- 1.7km from city centre',
#  '- 3.6km from city centre',
#  '- 5.1km from city centre',
#  '- 11.9km from city centre',
#  '- 4.4km from city centre',
#  '- 3.3km from city centre',
#  '- 4.9km from city centre',
#  '- 1.8km from city centre',
#  '- 1.8km from city centre',
#  '- 7.5km from city centre']

# %%
price = driver.find_elements(By.XPATH, '//strong[@class="current"]')

price_review = []
for i in price:
    review_ = i.text
    price_review.append(review_)

# %%
price_review
# Out:
# ['₹3,128',
#  '₹2,533',
#  '₹1,631',
#  '₹16,333',
#  '₹8,792',
#  '₹2,543',
#  '₹9,143',
#  '₹3,238',
#  '₹9,250',
#  '₹3,097',
#  '₹14,366',
#  '₹2,797',
#  '₹1,826',
#  '₹2,199',
#  '₹10,057',
#  '₹2,436',
#  '₹1,387',
#  '₹2,409',
#  '₹3,127',
#  '₹1,255',
#  '₹1,698',
#  '₹5,542',
#  '₹1,253',
#  '₹2,128',
#  '₹10,163',
#  '₹1,572',
#  '₹6,090',
#  '₹1,473',
#  '₹3,614',
#  '₹3,230',
#  '₹2,854',
#  '₹1,531',
#  '₹9,702',
#  '₹1,666',
#  '₹14,904',
#  '₹2,819',
#  '₹8,613',
#  '₹1,738',
#  '₹1,937',
#  '₹9,302',
#  '₹1,757',
#  '₹1,380']
